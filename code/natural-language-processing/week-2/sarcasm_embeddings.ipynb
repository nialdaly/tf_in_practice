# %%
import json
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

# %% [markdown]
# ### Data Loading

# %%
with open("../week-1/data/sarcasm.json", 'r') as f:
    datastore = json.load(f)

sentences = []
labels = []

for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %%
# Train sentences and labels
training_sentences = sentences[0:training_size]
training_labels = labels[0:training_size]

# Test sentences and labels
testing_sentences = sentences[training_size:]
testing_labels = labels[training_size:]

# %% [markdown]
# ### Data Preprocessing

# %%
# Creates the tokenizer
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
# Fits the tokenizer
tokenizer.fit_on_texts(training_sentences)

# Creates a word index
word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, 
                                maxlen=max_length, 
                                padding=padding_type, 
                                truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, 
                               maxlen=max_length, 
                               padding=padding_type, 
                               truncating=trunc_type)

# %%
# Creates numpy arrays
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)

testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %% [markdown]
# ### Model Architecture

# %%
# Defines the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, 
                              embedding_dim, 
                              input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compiles the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 16)           160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 24)                408
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 160,433
# Trainable params: 160,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Number of epochs for training
num_epochs = 30

# Fits the model and captures the history
history = model.fit(training_padded, 
                    training_labels, 
                    epochs=num_epochs, 
                    validation_data=(testing_padded, 
                                     testing_labels), 
                    verbose=2)
# Out:
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fc07e831560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fc07e831560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fc0811f8b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fc0811f8b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 4, expecting 3
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 625/625 - 1s - loss: 0.6575 - accuracy: 0.5999 - val_loss: 0.5530 - val_accuracy: 0.7855
# Epoch 2/30
# 625/625 - 1s - loss: 0.4188 - accuracy: 0.8357 - val_loss: 0.3836 - val_accuracy: 0.8362
# Epoch 3/30
# 625/625 - 1s - loss: 0.3067 - accuracy: 0.8796 - val_loss: 0.3502 - val_accuracy: 0.8563
# Epoch 4/30
# 625/625 - 1s - loss: 0.2575 - accuracy: 0.8992 - val_loss: 0.3411 - val_accuracy: 0.8599
# Epoch 5/30
# 625/625 - 1s - loss: 0.2229 - accuracy: 0.9138 - val_loss: 0.3430 - val_accuracy: 0.8551
# Epoch 6/30
# 625/625 - 1s - loss: 0.1950 - accuracy: 0.9260 - val_loss: 0.3512 - val_accuracy: 0.8527
# Epoch 7/30
# 625/625 - 1s - loss: 0.1732 - accuracy: 0.9352 - val_loss: 0.3609 - val_accuracy: 0.8557
# Epoch 8/30
# 625/625 - 1s - loss: 0.1550 - accuracy: 0.9431 - val_loss: 0.3755 - val_accuracy: 0.8530
# Epoch 9/30
# 625/625 - 1s - loss: 0.1409 - accuracy: 0.9500 - val_loss: 0.3957 - val_accuracy: 0.8489
# Epoch 10/30
# 625/625 - 1s - loss: 0.1276 - accuracy: 0.9553 - val_loss: 0.4112 - val_accuracy: 0.8501
# Epoch 11/30
# 625/625 - 1s - loss: 0.1152 - accuracy: 0.9606 - val_loss: 0.4327 - val_accuracy: 0.8480
# Epoch 12/30
# 625/625 - 1s - loss: 0.1054 - accuracy: 0.9646 - val_loss: 0.4635 - val_accuracy: 0.8438
# Epoch 13/30
# 625/625 - 1s - loss: 0.0977 - accuracy: 0.9667 - val_loss: 0.4821 - val_accuracy: 0.8427
# Epoch 14/30
# 625/625 - 1s - loss: 0.0891 - accuracy: 0.9700 - val_loss: 0.5073 - val_accuracy: 0.8405
# Epoch 15/30
# 625/625 - 1s - loss: 0.0812 - accuracy: 0.9733 - val_loss: 0.5479 - val_accuracy: 0.8362
# Epoch 16/30
# 625/625 - 1s - loss: 0.0751 - accuracy: 0.9764 - val_loss: 0.5839 - val_accuracy: 0.8343
# Epoch 17/30
# 625/625 - 1s - loss: 0.0692 - accuracy: 0.9786 - val_loss: 0.6076 - val_accuracy: 0.8281
# Epoch 18/30
# 625/625 - 1s - loss: 0.0637 - accuracy: 0.9804 - val_loss: 0.6291 - val_accuracy: 0.8322
# Epoch 19/30
# 625/625 - 1s - loss: 0.0581 - accuracy: 0.9823 - val_loss: 0.6836 - val_accuracy: 0.8278
# Epoch 20/30
# 625/625 - 1s - loss: 0.0541 - accuracy: 0.9839 - val_loss: 0.6926 - val_accuracy: 0.8274
# Epoch 21/30
# 625/625 - 1s - loss: 0.0506 - accuracy: 0.9850 - val_loss: 0.7295 - val_accuracy: 0.8222
# Epoch 22/30
# 625/625 - 1s - loss: 0.0455 - accuracy: 0.9865 - val_loss: 0.7674 - val_accuracy: 0.8196
# Epoch 23/30
# 625/625 - 1s - loss: 0.0420 - accuracy: 0.9876 - val_loss: 0.8048 - val_accuracy: 0.8219
# Epoch 24/30
# 625/625 - 1s - loss: 0.0395 - accuracy: 0.9881 - val_loss: 0.8322 - val_accuracy: 0.8196
# Epoch 25/30
# 625/625 - 1s - loss: 0.0373 - accuracy: 0.9890 - val_loss: 0.8717 - val_accuracy: 0.8190
# Epoch 26/30
# 625/625 - 1s - loss: 0.0334 - accuracy: 0.9905 - val_loss: 0.9218 - val_accuracy: 0.8161
# Epoch 27/30
# 625/625 - 1s - loss: 0.0298 - accuracy: 0.9914 - val_loss: 0.9458 - val_accuracy: 0.8174
# Epoch 28/30
# 625/625 - 1s - loss: 0.0285 - accuracy: 0.9920 - val_loss: 0.9827 - val_accuracy: 0.8120
# Epoch 29/30
# 625/625 - 1s - loss: 0.0273 - accuracy: 0.9919 - val_loss: 1.0323 - val_accuracy: 0.8159
# Epoch 30/30
# 625/625 - 1s - loss: 0.0257 - accuracy: 0.9927 - val_loss: 1.0637 - val_accuracy: 0.8120

# %% [markdown]
# ### Model Evaluation

# %%
import matplotlib.pyplot as plt

# %%
# Plot graphs function
def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# Calls the plot graphs function    
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
# Generates a reverse word index
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# Decode sentence function
def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_sentence(training_padded[0]))
print(training_sentences[2])
print(labels[2])
# Out:
# former <OOV> store clerk sues over secret 'black <OOV> for minority shoppers ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
# mom starting to fear son's web series closest thing she will have to grandchild
# 1

# %%
e = model.layers[0]
weights = e.get_weights()[0]
# Shape: (vocab_size, embedding_dim)
print(weights.shape)
# Out:
# (10000, 16)

# %%
import io

# %%
# out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
# out_m = io.open('meta.tsv', 'w', encoding='utf-8')

# for word_num in range(1, vocab_size):
#     word = reverse_word_index[word_num]
#     embeddings = weights[word_num]
#     out_m.write(word + "\n")
#     out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")

# out_v.close()
# out_m.close()

# %%
sentence = [
    "granny starting to fear spiders in the garden might be real", 
    "game of thrones season finale showing this sunday night"]

sequences = tokenizer.texts_to_sequences(sentence)

padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

print(model.predict(padded))
# Out:
# [[9.5619166e-01]
#  [3.2627931e-06]]
